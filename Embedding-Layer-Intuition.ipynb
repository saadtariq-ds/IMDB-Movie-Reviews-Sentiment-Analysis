# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers, losses

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data

# %%
sentences = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good',
]

# %%
sentences
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %% [markdown]
# ## Define the Vocabulary Size

# %%
vocabulary_size = 10000

# %%
one_hot_representation = [one_hot(words, vocabulary_size) for words in sentences]
one_hot_representation
# Out:
# [[73, 1816, 6056, 2306],
#  [73, 1816, 6056, 2474],
#  [73, 7999, 6056, 6642],
#  [8909, 7556, 9977, 4276],
#  [8909, 7556, 9977, 9306, 3984],
#  [5663, 73, 5418, 6056, 9333],
#  [8226, 9829, 314, 9306]]

# %% [markdown]
# ## Word Embedding Representation

# %%
sentence_length = 8

# %%
embedded_documents = pad_sequences(
    one_hot_representation,
    padding='pre',
    # padding='post',
    maxlen=sentence_length
)

embedded_documents
# Out:
# array([[   0,    0,    0,    0,   73, 1816, 6056, 2306],
#        [   0,    0,    0,    0,   73, 1816, 6056, 2474],
#        [   0,    0,    0,    0,   73, 7999, 6056, 6642],
#        [   0,    0,    0,    0, 8909, 7556, 9977, 4276],
#        [   0,    0,    0, 8909, 7556, 9977, 9306, 3984],
#        [   0,    0,    0, 5663,   73, 5418, 6056, 9333],
#        [   0,    0,    0,    0, 8226, 9829,  314, 9306]], dtype=int32)

# %% [markdown]
# ## Feature Representation and Model Training

# %%
dimensions = 10

# %%
optimizer = optimizers.Adam(learning_rate=0.001)
loss = losses.MeanSquaredError()

# %%
model = Sequential()

model.add(Embedding(input_dim=vocabulary_size, output_dim=dimensions, input_shape=(sentence_length,)))

model.compile(
    optimizer=optimizer,
    loss=loss
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_documents)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# array([[[-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [ 0.02905089, -0.03191014, -0.04711958, -0.03315663,
#           0.00977664, -0.01757487, -0.01024494, -0.04969617,
#           0.01395838,  0.04868854],
#         [ 0.01384025, -0.01481377,  0.03252225, -0.02803394,
#           0.00848915, -0.04511019, -0.01351049, -0.02306713,
#          -0.00836868, -0.00919125],
#         [ 0.03305507, -0.0441818 , -0.01678448, -0.00842453,
#          -0.04959631, -0.00655193,  0.02796482,  0.01872108,
#          -0.01495004, -0.02978683],
#         [-0.00355275, -0.01041641,  0.03996486, -0.03624884,
#           0.02545228, -0.00461536,  0.03391114,  0.04614656,
#           0.02458388, -0.00778836]],
#
#        [[-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [ 0.02905089, -0.03191014, -0.04711958, -0.03315663,
#           0.00977664, -0.01757487, -0.01024494, -0.04969617,
#           0.01395838,  0.04868854],
#         [ 0.01384025, -0.01481377,  0.03252225, -0.02803394,
#           0.00848915, -0.04511019, -0.01351049, -0.02306713,
#          -0.00836868, -0.00919125],
#         [ 0.03305507, -0.0441818 , -0.01678448, -0.00842453,
#          -0.04959631, -0.00655193,  0.02796482,  0.01872108,
#          -0.01495004, -0.02978683],
#         [ 0.00154474, -0.01688291,  0.02233293,  0.04151133,
#           0.03775277, -0.00709039, -0.01047875,  0.03069517,
#           0.04268679,  0.01940696]],
#
#        [[-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [ 0.02905089, -0.03191014, -0.04711958, -0.03315663,
#           0.00977664, -0.01757487, -0.01024494, -0.04969617,
#           0.01395838,  0.04868854],
#         [-0.020223  , -0.02015117,  0.04017642,  0.02842495,
#           0.0207036 ,  0.03477004, -0.01272475,  0.01238779,
#          -0.04447179,  0.03245446],
#         [ 0.03305507, -0.0441818 , -0.01678448, -0.00842453,
#          -0.04959631, -0.00655193,  0.02796482,  0.01872108,
#          -0.01495004, -0.02978683],
#         [-0.01349784, -0.02922213, -0.04876328, -0.00897392,
#          -0.0443846 , -0.04393278, -0.02176908,  0.04944224,
#          -0.02278838, -0.01769928]],
#
#        [[-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.03618472,  0.00293874,  0.00803854, -0.00117989,
#          -0.02703909,  0.01849563,  0.00792518,  0.03326844,
#           0.02958347, -0.02407807],
#         [ 0.02929145, -0.00205034, -0.04853015,  0.04416553,
#           0.03294012,  0.03104648, -0.04666858,  0.04115696,
#          -0.04485446, -0.01603979],
#         [-0.04708073,  0.01515994, -0.04854412,  0.04512176,
#          -0.04426717,  0.00785965,  0.03175229, -0.00942962,
#           0.00937261, -0.0177217 ],
#         [-0.02214592, -0.03131609,  0.04620471, -0.02050188,
#           0.01946625,  0.00215768,  0.0325423 , -0.01904039,
#          -0.01131239, -0.04028505]],
#
#        [[-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.03618472,  0.00293874,  0.00803854, -0.00117989,
#          -0.02703909,  0.01849563,  0.00792518,  0.03326844,
#           0.02958347, -0.02407807],
#         [ 0.02929145, -0.00205034, -0.04853015,  0.04416553,
#           0.03294012,  0.03104648, -0.04666858,  0.04115696,
#          -0.04485446, -0.01603979],
#         [-0.04708073,  0.01515994, -0.04854412,  0.04512176,
#          -0.04426717,  0.00785965,  0.03175229, -0.00942962,
#           0.00937261, -0.0177217 ],
#         [-0.04611889,  0.03812251,  0.02943661, -0.04208361,
#           0.04735189,  0.0082253 , -0.03088582, -0.00244885,
#           0.0433946 ,  0.00271209],
#         [ 0.01529207, -0.02357446,  0.0334415 ,  0.03693748,
#           0.0021134 ,  0.04651517,  0.02167488,  0.00962583,
#           0.00836142,  0.00289483]],
#
#        [[-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.03127927, -0.04748703, -0.01298015, -0.02665329,
#           0.01262491,  0.04533092, -0.02721442, -0.03041049,
#          -0.03219911,  0.00911801],
#         [ 0.02905089, -0.03191014, -0.04711958, -0.03315663,
#           0.00977664, -0.01757487, -0.01024494, -0.04969617,
#           0.01395838,  0.04868854],
#         [ 0.03030672, -0.01996228, -0.02213689, -0.00510997,
#          -0.02587361, -0.03555887, -0.0196872 ,  0.00259806,
#          -0.00095124,  0.04739604],
#         [ 0.03305507, -0.0441818 , -0.01678448, -0.00842453,
#          -0.04959631, -0.00655193,  0.02796482,  0.01872108,
#          -0.01495004, -0.02978683],
#         [-0.04846232, -0.04211815, -0.02989949, -0.02202705,
#          -0.00221048,  0.00969576,  0.03904745, -0.03585923,
#           0.03954962, -0.02192544]],
#
#        [[-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.01311555,  0.02888575,  0.04102648, -0.0190951 ,
#           0.04369804, -0.03273895, -0.031401  , -0.00678832,
#          -0.04824839,  0.04286039],
#         [-0.02673023, -0.03082618,  0.00170826,  0.03567887,
#          -0.03365149, -0.0093838 , -0.04922278, -0.0195865 ,
#           0.04628279,  0.0326408 ],
#         [ 0.04229248,  0.02452889, -0.03904115,  0.03696126,
#          -0.03785385,  0.02856067, -0.01535438,  0.0155797 ,
#          -0.00034151, -0.0347087 ],
#         [-0.04611889,  0.03812251,  0.02943661, -0.04208361,
#           0.04735189,  0.0082253 , -0.03088582, -0.00244885,
#           0.0433946 ,  0.00271209]]], dtype=float32)

# %%
embedded_documents[0]
# Out:
# array([   0,    0,    0,    0,   73, 1816, 6056, 2306], dtype=int32)

# %%
input_example = np.expand_dims(embedded_documents[0], axis=0)
model.predict(input_example)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# array([[[-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [-0.00596559,  0.03054111,  0.04689955, -0.00282722,
#           0.03639487, -0.0014166 , -0.00207208,  0.00443318,
#           0.04220575,  0.04393994],
#         [ 0.02905089, -0.03191014, -0.04711958, -0.03315663,
#           0.00977664, -0.01757487, -0.01024494, -0.04969617,
#           0.01395838,  0.04868854],
#         [ 0.01384025, -0.01481377,  0.03252225, -0.02803394,
#           0.00848915, -0.04511019, -0.01351049, -0.02306713,
#          -0.00836868, -0.00919125],
#         [ 0.03305507, -0.0441818 , -0.01678448, -0.00842453,
#          -0.04959631, -0.00655193,  0.02796482,  0.01872108,
#          -0.01495004, -0.02978683],
#         [-0.00355275, -0.01041641,  0.03996486, -0.03624884,
#           0.02545228, -0.00461536,  0.03391114,  0.04614656,
#           0.02458388, -0.00778836]]], dtype=float32)
